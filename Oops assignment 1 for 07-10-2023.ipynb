# %%
#Problem 1: Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance. Implement methods to deposit and withdraw money from the account.


class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount} into the account. New balance: ${self.balance}")
        else:
            print("Invalid deposit amount. Please deposit a positive amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount} from the account. New balance: ${self.balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount. Please check your balance and the amount to withdraw.")

    def get_balance(self):
        return self.balance

    def __str__(self):
        return f"Account Number: {self.account_number}\nAccount Holder Name: {self.account_holder_name}\nBalance: ${self.balance}"

# Example usage of the BankAccount class
if __name__ == "__main__":
    account = BankAccount("123456", "Soor Sharma", 1000)
    print(account)
    account.deposit(1500)
    account.withdraw(200)
    account.withdraw(1500)
    print(account)
#In this example, we create a BankAccount class with an __init__ constructor method to initialize the attributes, deposit and withdraw methods to perform transactions, a get_balance method to retrieve the account balance, and a __str__ method to provide a string representation of the account.
# Out:
# Account Number: 123456
# Account Holder Name: Soor Sharma
# Balance: $1000
# Deposited $1500 into the account. New balance: $2500
# Withdrew $200 from the account. New balance: $2300
# Withdrew $1500 from the account. New balance: $800
# Account Number: 123456
# Account Holder Name: Soor Sharma
# Balance: $800

# %%
#Problem 2: Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. Implement methods to calculate the yearly bonus and display employee details.


class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self, bonus_percentage):
        if bonus_percentage >= 0:
            bonus = (bonus_percentage / 100) * self.salary
            return bonus
        else:
            return 0

    def display_employee_details(self):
        print(f"Employee ID: {self.employee_id}")
        print(f"Name: {self.name}")
        print(f"Salary: ${self.salary:.2f}")

# Example usage of the Employee class

if __name__ == "__main":
    employee = Employee("E12345", "Sai Das", 60000)
    employee.display_employee_details()
    bonus_percentage = 10  # 10% bonus
    yearly_bonus = employee.calculate_yearly_bonus(bonus_percentage)
    print(f"Yearly Bonus: ${yearly_bonus:.2f}")
    
#In this example, we create an Employee class with an __init__ constructor method to initialize the attributes, a calculate_yearly_bonus method to calculate the yearly bonus based on a given bonus percentage, and a display_employee_details method to display the employee's details.

#The example usage at the end demonstrates creating an employee, displaying their details, and calculating and displaying their yearly bonus.

# %%
#Problem 3: Vehicle Rental Create a class representing a vehicle rental system. Implement methods to rent a vehicle, return a vehicle, and display available vehicles.

class VehicleRentalSystem:
    def __init__(self):
        self.available_vehicles = {}

    def add_vehicle(self, vehicle_id, vehicle_type):
        if vehicle_id not in self.available_vehicles:
            self.available_vehicles[vehicle_id] = vehicle_type
            print(f"Added {vehicle_type} with ID {vehicle_id} to the available vehicles.")
        else:
            print(f"Vehicle with ID {vehicle_id} already exists in the system.")

    def rent_vehicle(self, vehicle_id):
        if vehicle_id in self.available_vehicles:
            vehicle_type = self.available_vehicles.pop(vehicle_id)
            print(f"Rented {vehicle_type} with ID {vehicle_id}.")
        else:
            print(f"Vehicle with ID {vehicle_id} is not available for rent.")

    def return_vehicle(self, vehicle_id, vehicle_type):
        if vehicle_id not in self.available_vehicles:
            self.available_vehicles[vehicle_id] = vehicle_type
            print(f"Returned {vehicle_type} with ID {vehicle_id}.")
        else:
            print(f"This vehicle is already available in the system.")

    def display_available_vehicles(self):
        print("Available vehicles:")
        if not self.available_vehicles:
            print("Number of available vehicles: 0")
        else:
            for vehicle_id, vehicle_type in self.available_vehicles.items():
                print(f"ID: {vehicle_id}, Type: {vehicle_type}")
            print(f"Number of available vehicles: {len(self.available_vehicles)}")

if __name__ == "__main__":
    rental_system = VehicleRentalSystem()

    rental_system.display_available_vehicles()
    
    rental_system.add_vehicle("V001", "Car")
    rental_system.add_vehicle("V002", "Bike")
    rental_system.add_vehicle("V003", "Scooter")

    rental_system.rent_vehicle("V001")

    rental_system.display_available_vehicles()

    rental_system.return_vehicle("V001", "Car")

    rental_system.display_available_vehicles()
# Out:
# Available vehicles:
# Number of available vehicles: 0
# Added Car with ID V001 to the available vehicles.
# Added Bike with ID V002 to the available vehicles.
# Added Scooter with ID V003 to the available vehicles.
# Rented Car with ID V001.
# Available vehicles:
# ID: V002, Type: Bike
# ID: V003, Type: Scooter
# Number of available vehicles: 2
# Returned Car with ID V001.
# Available vehicles:
# ID: V002, Type: Bike
# ID: V003, Type: Scooter
# ID: V001, Type: Car
# Number of available vehicles: 3

# %%
#Problem 4: Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books, and display available books.

class Book:
    def __init__(self, title):
        self.title = title
        self.is_borrowed = False

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book_title):
        self.books.append(Book(book_title))
        print(f'Added "{book_title}" to the library.')

    def borrow_book(self, book_title):
        for book in self.books:
            if book.title.lower() == book_title.lower() and not book.is_borrowed:
                book.is_borrowed = True
                print(f'Borrowed "{book_title}" from the library.')
                return
        print(f'"{book_title}" is not available in the library or is already borrowed.')

    def display_available_books(self):
        available_books = [book.title for book in self.books if not book.is_borrowed]
        print("Available books in the library:")
        for title in available_books:
            print(title)
        available_books_count = len(available_books)
        print(f"{available_books_count} books ({', '.join(available_books)})")

# Example usage:
if __name__ == "__main__":
    library = Library()
    
    library.display_available_books()

    library.add_book("A Time to Kill")
    library.add_book("The Broker")
    library.add_book("Mein kampf")

    library.display_available_books()

    library.add_book("As the Crow Flies")

    library.borrow_book("A Time to Kill")

    library.display_available_books()
# Out:
# Available books in the library:
# 0 books ()
# Added "A Time to Kill" to the library.
# Added "The Broker" to the library.
# Added "Mein kampf" to the library.
# Available books in the library:
# A Time to Kill
# The Broker
# Mein kampf
# 3 books (A Time to Kill, The Broker, Mein kampf)
# Added "As the Crow Flies" to the library.
# Borrowed "A Time to Kill" from the library.
# Available books in the library:
# The Broker
# Mein kampf
# As the Crow Flies
# 3 books (The Broker, Mein kampf, As the Crow Flies)

# %%
#Problem 5: Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the inventory, update product quantity, and display available products.


class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

class Inventory:
    def __init__(self):
        self.products = []

    def add_product(self, product):
        self.products.append(product)

    def update_quantity(self, product_name, new_quantity):
        for product in self.products:
            if product.name.lower() == product_name.lower():  # Case-insensitive comparison
                product.quantity = new_quantity
                return

        print(f"Product with name '{product_name}' not found in the inventory.")

    def display_available_products(self):
        print("Available products in the inventory:")
        for product in self.products:
            print(f"Name: {product.name}, Price: ${product.price}, Quantity: {product.quantity}")

if __name__ == "__main__":
    inventory = Inventory()

    inventory.add_product(Product("Widget", 10.99, 50))
    inventory.add_product(Product("Gadget", 19.99, 30))
    inventory.add_product(Product("Doodad", 5.99, 20))

   
    inventory.display_available_products()

    print("Adding product: Doodad (Price: $5.99, Quantity: 20) to the inventory...")
    inventory.add_product(Product("Doodad", 5.99, 20))

    print("Updating the quantity of products...")
    inventory.update_quantity("Widget", 45)

   
    inventory.display_available_products()
# Out:
# Available products in the inventory:
# Name: Widget, Price: $10.99, Quantity: 50
# Name: Gadget, Price: $19.99, Quantity: 30
# Name: Doodad, Price: $5.99, Quantity: 20
# Adding product: Doodad (Price: $5.99, Quantity: 20) to the inventory...
# Updating the quantity of products...
# Available products in the inventory:
# Name: Widget, Price: $10.99, Quantity: 45
# Name: Gadget, Price: $19.99, Quantity: 30
# Name: Doodad, Price: $5.99, Quantity: 20
# Name: Doodad, Price: $5.99, Quantity: 20

# %%
#Problem 6: Shape Calculation Create a class representing a shape with attributes like length, width, and height. Implement methods to calculate the area and perimeter of the shape.

import math

class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

class Triangle(Shape):
    def calculate_area(self):
        return 0.5 * self.length * self.height

    def calculate_perimeter(self):
        return self.length + self.width + self.height

# Input for dimensions
length = float(input("Enter length: "))
width = float(input("Enter width: "))
height = float(input("Enter height: "))

# Create instances of the shapes with specific dimensions
rectangle = Rectangle(length=length, width=width)
triangle = Triangle(length=length, height=height, width=width)

# Calculate and print the area and perimeter of each shape
print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())

print("Triangle Area:", triangle.calculate_area())
print("Triangle Perimeter:", triangle.calculate_perimeter())
# Out:
# Enter length:  10
# Enter width:  20
# Enter height:  10
# Rectangle Area: 200.0
# Rectangle Perimeter: 60.0
# Triangle Area: 50.0
# Triangle Perimeter: 40.0

# %%
import math

class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3):
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def calculate_area(self):
        return 0.5 * self.base * self.height

    def calculate_perimeter(self):
        return self.side1 + self.side2 + self.side3


# Example usage
r = 7
circle = Circle(r)
circle_area = circle.calculate_area()
circle_perimeter = circle.calculate_perimeter()

print("Radius of the circle:",r)
print("Circle Area:", circle_area)
print("Circle Perimeter:", circle_perimeter)


l = 5
w = 7
rectangle = Rectangle(l, w)
rectangle_area = rectangle.calculate_area()
rectangle_perimeter = rectangle.calculate_perimeter()
print("\nRectangle: Length =",l," Width =",w)
print("Rectangle Area:", rectangle_area)
print("Rectangle Perimeter:", rectangle_perimeter)

base = 5
height = 4
s1 = 4
s2 = 3
s3 = 5

print("\nTriangle: Base =",base," Height =",height," side1 =",s1," side2 =",s2," side3 =",s3)
triangle = Triangle(base,height,s1,s2,s3)
triangle_area = triangle.calculate_area()
triangle_perimeter = triangle.calculate_perimeter()
print("Triangle Area:", triangle_area)
print("Triangle Perimeter:", triangle_perimeter)
# Out:
# Radius of the circle: 7
# Circle Area: 153.93804002589985
# Circle Perimeter: 43.982297150257104
#
# Rectangle: Length = 5  Width = 7
# Rectangle Area: 35
# Rectangle Perimeter: 24
#
# Triangle: Base = 5  Height = 4  side1 = 4  side2 = 3  side3 = 5
# Triangle Area: 10.0
# Triangle Perimeter: 12

# %%
#Problem 7: Student Management Create a class representing a student with attributes like student ID, name, and grades. Implement methods to calculate the average grade and display student details.

class Student:
    student_count = 0

    def __init__(self, name):
        Student.student_count += 1
        self.student_id = Student.student_count
        self.name = name
        self.grades = {}
        self.average_grade = 0

    def input_grades(self, subjects):
        print(f"Enter grades for {self.name}:")
        for subject in subjects:
            grade = int(input(f"Enter grade for {subject}: "))
            self.grades[subject] = grade
        self.calculate_average_grade()

    def calculate_average_grade(self):
        total_grades = sum(self.grades.values())
        self.average_grade = total_grades / len(self.grades)

    def display_student_details(self):
        print(f"\nStudent ID: {self.student_id}")
        print(f"Name: {self.name}")
        print(f"Grades: {', '.join([f'{subj}: {grade}' for subj, grade in self.grades.items()])}")
        print(f"Average Grade: {self.average_grade:.2f}")

        if all(grade >= 35 for grade in self.grades.values()):
            if self.average_grade > 70:
                print("Passed with Distinction")
            else:
                print("Passed")
        else:
            print("Failed in: ", end="")
            for subject, grade in self.grades.items():
                if grade < 35:
                    print(subject, end=", ")
            print()

def main():
    num_students = 2
    subjects = ["Math", "Science", "English", "Social Science"]
    students = []

    for i in range(num_students):
        name = input(f"Enter the name for student {i + 1}: ")
        student = Student(name)
        student.input_grades(subjects)
        students.append(student)

    for student in students:
        student.display_student_details()

if __name__ == "__main__":
    main()
# Out:
# Enter the name for student 1:  suraj
# Enter grades for suraj:
# Enter grade for Math:  80
# Enter grade for Science:  60
# Enter grade for English:  90
# Enter grade for Social Science:  70
# Enter the name for student 2:  raj
# Enter grades for raj:
# Enter grade for Math:  34
# Enter grade for Science:  50
# Enter grade for English:  40
# Enter grade for Social Science:  60
# Student ID: 1
# Name: suraj
# Grades: Math: 80, Science: 60, English: 90, Social Science: 70
# Average Grade: 75.00
# Passed with Distinction
#
# Student ID: 2
# Name: raj
# Grades: Math: 34, Science: 50, English: 40, Social Science: 60
# Average Grade: 46.00
# Failed in: Math,

# %%
#Problem 8: Email Management Create a class representing an email with attributes like sender, recipient, and subject. Implement methods to send an email and display email details.


class Email:
    def __init__(self, sender, recipient, subject):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.message = None

    def send_email(self, message):
        self.message = message
        print("Email Details:")
        print(f"Sender: {self.sender}")
        print(f"Recipient: {self.recipient}")
        print(f"Subject: {self.subject}")
        print(f"Email sent from {self.sender} to {self.recipient}")
        print(f"Subject: {self.subject}")
        print("Message:")
        print(message)


class EmailReceived(Email):
    def receive_email(self):
        print(f"Email received from {self.sender}")
        print(f"Subject: {self.subject}")
        print("Message:")
        print(self.message)


# Example usage
if __name__ == "__main__":
    sender_email = "sender@example.com"
    recipient_email = "recipient@example.com"
    email_subject = "Hello!"
    email_message = "This is a test email."

    sent_email = Email(sender_email, recipient_email, email_subject)
    received_email = EmailReceived(sender_email, recipient_email, email_subject)

    sent_email.send_email(email_message)
    print("\n")
    received_email.receive_email()
# Out:
# Email Details:
# Sender: sender@example.com
# Recipient: recipient@example.com
# Subject: Hello!
# Email sent from sender@example.com to recipient@example.com
# Subject: Hello!
# Message:
# This is a test email.
#
#
# Email received from sender@example.com
# Subject: Hello!
# Message:
# None

# %%
#Problem 9: Social Media Profile Create a class representing a social media profile with attributes like username and posts. Implement methods to add posts, display posts, and search for posts by keyword.

class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, text):
        """Add a new post to the profile."""
        self.posts.append(text)

    def display_posts(self):
        """Display all posts on the profile."""
        if not self.posts:
            pass
        else:
            print(f"{self.username}'s posts:")
            for i, post in enumerate(self.posts, start=1):
                print(f"{i}. {post}")

    def search_posts_by_keyword(self, keyword):
        """Search for posts that contain the given keyword and display them."""
        matching_posts = [post for post in self.posts if keyword in post]
        if not matching_posts:
            pass
        else:
            print(f"Posts by {self.username} containing '{keyword}':")
            for i, post in enumerate(matching_posts, start=1):
                print(f"{i}. {post}")

if __name__ == "__main__":
    username = "Suraj Sharma"
    profile = SocialMediaProfile(username)

    print(f"{username}'s Social Media Profile")
    print("-------------------------------")

    profile.display_posts()

    print("\nAdding new posts:")
    profile.add_post("Just had a delicious meal at NeemTree Restaurant.")
    profile.add_post("Watching IND vs PAK live Cricket worldcup 2023 match! #Cricketlover ")
    profile.add_post("Exploring new hiking trails.")
    profile.display_posts()

    print("\nSearching for posts about 'Cricket':")
    profile.search_posts_by_keyword("Cricket")
# Out:
# Suraj Sharma's Social Media Profile
# -------------------------------
#
# Adding new posts:
# Suraj Sharma's posts:
# 1. Just had a delicious meal at NeemTree Restaurant.
# 2. Watching IND vs PAK live Cricket worldcup 2023 match! #Cricketlover
# 3. Exploring new hiking trails.
#
# Searching for posts about 'Cricket':
# Posts by Suraj Sharma containing 'Cricket':
# 1. Watching IND vs PAK live Cricket worldcup 2023 match! #Cricketlover

# %%
#10. Problem 10: ToDo List Create a class representing a ToDo list with attributes like tasks and due dates. Implement methods to add tasks, mark tasks as completed, and display pending tasks.

class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task, due_date):
        """Add a new task to the ToDo list."""
        self.tasks.append({"task": task, "due_date": due_date, "completed": False})

    def mark_task_completed(self, task):
        """Mark a task as completed."""
        for item in self.tasks:
            if item["task"] == task:
                item["completed"] = True

    def display_tasks(self):
        """Display the list of tasks and pending tasks."""
        print("ToDo List")
        print("----------")
        print("\nList of tasks:")
        for i, item in enumerate(self.tasks, start=1):
            print(f"{i}. Task: {item['task']} (Due Date: {item['due_date']})")

    def display_pending_tasks(self):
        """Display pending tasks."""
        pending_tasks = [item for item in self.tasks if not item["completed"]]
        print("\nPending tasks:")
        for i, item in enumerate(pending_tasks, start=1):
            print(f"{i}. Task: {item['task']} (Due Date: {item['due_date']})")

# Example usage:
if __name__ == "__main__":
    todo_list = ToDoList()

    todo_list.add_task("Buy groceries", "2023-10-31")
    todo_list.add_task("Finish work report", "2023-11-05")
    todo_list.add_task("Call a friend", "2023-10-28")

    todo_list.display_tasks()

    print("\nCalled a friend - Marked 'Call a friend' as completed.")
    todo_list.mark_task_completed("Call a friend")

    todo_list.display_pending_tasks()
# Out:
# ToDo List
# ----------
#
# List of tasks:
# 1. Task: Buy groceries (Due Date: 2023-10-31)
# 2. Task: Finish work report (Due Date: 2023-11-05)
# 3. Task: Call a friend (Due Date: 2023-10-28)
#
# Called a friend - Marked 'Call a friend' as completed.
#
# Pending tasks:
# 1. Task: Buy groceries (Due Date: 2023-10-31)
# 2. Task: Finish work report (Due Date: 2023-11-05)
